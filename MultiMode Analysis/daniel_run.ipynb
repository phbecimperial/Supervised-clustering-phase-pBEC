# %%
import daniel_func

#Example of timestamps format. Need first and last timestamp
t_chunks = [['20240814_172304', '20240814_213106'], 
]

#Write your system path
#Can be one level above folders
sys_path = r'C:\Users\natak\OneDrive - Imperial College London\Documents\University\Year 4\MSci Project-r018104\All_data\202408'

image_dir = sys_path
#Make new folder or everything will be deleted
files, metas = daniel_func.open_img_files(t_chunks, image_dir)
print(len(files))
data = daniel_func.data_from_metas(metas, files)

data['position']
